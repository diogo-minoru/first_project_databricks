# %%
# %sql
use catalog first_project;

create database first_database;

show databases

# %%
# %sql
alter database raw_public set dbproperties (comment = "Raw data from postgresql");
describe database raw_public

# %%
# %sql
describe database extended raw_public

# %%
# %sql
create or replace table first_database.first_table (name string, age integer, gender string);

insert into first_database.first_table values ('Th', 30, 'Female'), ('Diogo', 28, 'Homem');

select *
from first_database.first_table

# %%
# %sql
describe table first_database.first_table

# %%
# %sql
show create table raw_public.orderrows
